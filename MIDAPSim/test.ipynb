# %%
import os
import numpy as np
if os.path.isfile("error.log"):
    os.remove("error.log")

# %%
run tools/test_system.py -n mobilenet_v2 -fs -q --debug

# %%
tr.cm.shared_compile_info.model._str2layer['Sum8'].op

# %%
print(tr.midap_simulator[0].data_info_dict['Sum8'].compare_data[-1, 0, : 32])
print(tr.midap_simulator[0].data_info_dict['Sum8'].data[-1, 0, : 32])

# %%
tr.midap_simulator[0].data_info_dict['Sum1'].diff_arr[0, 1,  : ]

# %%
tr.si[0].processing_order[42].control_info.wmem_info.__dict__

# %%
tr.midap_simulator[0].memory_controller.memory_manager.fmem[0,16:64]

# %%
tr.midap_simulator[0].memory_controller.memory_manager.dram_data[2][25088+16:25088+64]

# %%
tr.midap_simulator[0].data_info_dict['Sum8'].data[-1, 0, : 32]

# %%
print(tr.midap_simulator[0].data_info_dict['Conv6'].data[0,1,:])
print(tr.cm.core_info[0].compile_info.model._str2tensor['Conv6'])

# %%
print(tr.midap_simulator[0].data_info_dict['Conv4'].data[0,1,:])
print(tr.cm.core_info[0].compile_info.model._str2tensor['Conv4'])

# %%
tr.cm.core_info[0].compile_info.model._str2tensor['Sum1'].data[0, 0, 1, :]

# %%
tr.cm.core_info[0].compile_info.model._str2tensor['Conv4'].data[0, 0, 1, :] + tr.cm.core_info[0].compile_info.model._str2tensor['Conv6'].data[0, 0, 1, :]

# %%
tr.cm.core_info[0].compile_info.model._str2layer['Sum8'].in_vtensors

# %%
run tools/test_system.py -q -n mobilenet_v3_large -nc 2 -fs --spm_config 2 6000

# %%
tr.cm.core_info[0].compile_info.layers[9].behavior

# %%
run run_from_file.py -d temp2 -p mv3_4

# %%
tr.cm.core_info[0].compile_info.layers[9].mapping.input

# %%
[list(enumerate([l.name for l in tr.cm.core_info[i].compile_info.layers])) for i in range(4)]

# %%
t = tr.si[0].compile_info.layers['Sum1']
t.main_op.quant_info.__dict__

# %%
tr.cm.core_info[0].compile_info.model._str2layer['Conv1'].quant_info

# %%
tr.cm.core_info[0].compile_info.model._str2layer['Conv1'].out_tensor.data

# %%
t2 = tr.midap_simulator[2].data_info_dict['Conv22'].data
t1 = tr.midap_simulator[2].data_info_dict['Conv24'].data

# %%
np.sum(tr.midap_simulator[3].data_info_dict['Sum7'].diff_arr[:,:,:96])

# %%
tr.midap_simulator[0].memory_controller.memory_manager.dram_dict

# %%
tr.cm.core_info[0].compile_info.wmem_info_dict

# %%
tr.bc[0].compile_info.layers['Conv1'].main_op.quant_info.__dict__

# %%
a1, addr1 = tr.midap_simulator[3].memory_controller.memory_manager.dram_dict['Conv24']
a2, addr2 = tr.midap_simulator[3].memory_controller.memory_manager.dram_dict['Conv22']

# %%
np.sum((t2 - tr.midap_simulator[3].memory_controller.memory_manager.dram_data[a2][addr2:addr2+t2.size].reshape(t2.shape))[:,:,:96])

# %%
from data_structure.attrdict import from_attrdict_to_dict, from_dict_to_attrdict
tr.si[2].config['DRAM']['OFFSET']['IO'].dtype

# %%
src_layers = tr.cm.dependency_info.global_dependency['Prefetch_Linear1_w']
s=  tr.cm.dependency_info

# %%
m = tr.cm.core_info[0].compile_info.model
l = m._str2layer['Conv8']

# %%
l = tr.si[0].compile_info.layers['Sum7']
l.processing_info.behavior_info[1].write_info.__dict__

# %%
np.sum(tr.midap_simulator[0].data_info_dict['Sum1'].diff_arr[:,:,16])
# tr.cm.shared_compile_info.model._str2layer['GlobalPool1'].reduction

# %%
tr.midap_simulator[0].data_info_dict['DWConv13'].compare_data[:1,:1,512:576]

# %%
tr.midap_simulator[0].data_info_dict['DWConv13'].data[:1,:1,512:576]

# %%
ld = tr.midap_simulator[0].memory_controller.memory_manager.dram_data

# %%
addr = 1442752
comp = ld[2][addr:addr+512*1024]

# %%
tr.midap_simulator[0].data_info_dict['DWConv1'].data.sum(axis=0).sum(axis=0)

# %%
from midap_simulator.shared_info import PrefetchManager
PrefetchManager.get_trace()

# %%
np.sum(tr.midap_simulator[1].data_info_dict['Conv13'].diff_arr[8:,:,:])

# %%
tr.midap_simulator[1].memory_controller.memory_manager.config.MODEL.QUANTIZED

# %%
weight = tr.cm.core_info[0].compile_info.model._str2tensor['Conv1_w'].data

# %%
tr.si[1].processing_order[0].control_info.sync_info.__dict__

# %%
for _, l in tr.bc[1].compile_info.layers.items():
    print(f"{l}\n ==========================\n {l.processing_info}\n ======================")

# %%
for _, l in tr.bc[0].compile_info.layers.items():
    print(f"{l}\n ==========================\n {l.processing_info.mapping_info.__dict__}\n ======================")

# %%
tr.cm.core_info[0].compile_info.model._str2tensor['Conv1_b'].data.size

# %%
tr.si[0].processing_order[0].control_info.wmem_info.__dict__

# %%
tr.generic_model.operator_dict['UpsampleZero1'].scale

# %%
sim = tr.midap_simulator[1]
np.sum(sim.data_info_dict['Conv29'].diff_arr[:,:,0])

# %%
tr.cm.system_compiler.mapping_compiler._model._str2layer['Sum1'].in_vtensors

# %%
run test.py -n mobilenet_v2 -fs -nb 8 -f 128

# %%
tr.cm.shared_compile_info.wmem_info_dict

# %%
[s.size for s in tr.si.dram_data]

# %%
(14 * 14* 64) + 402432

# %%
112 * 112 * 32

# %%
tr.midap_simulator.memory_controller.memory_manager.dram_dict

# %%
import numpy as np

# %%
np.sum(s_tr.midap_simulator[0].memory_controller.memory_manager.dram_data[0][:400000] - tr.midap_simulator.memory_controller.memory_manager.dram_data[0][:400000])

# %%
list(None)

# %%
from config import cfg
cfg

# %%
tr

# %%
int(0)

# %%
import torch
import numpy as np

# %%
x = torch.from_numpy(np.array([[[[1,2,3],[5,6,7]]]], dtype=np.float32))

# %%
torch.nn.functional.interpolate(x, size = (6, 12),mode='bilinear', align_corners=False)

# %%
x.shape
