# %%
import numpy as np
from system_test_wrapper import SystemTestWrapper
from code_generator.opcode_tool import OpcodeTool
import os
if os.path.isfile("error.log"):
    os.remove("error.log")

# %%
run tools/generate_binary.py -d temp -p sr50_q -gen -od /share/golden/sr50

# %%
run tools/generate_binary.py -d temp -p mv2_q -gen -od /share/golden/mv2 -dr

# %%
run tools/generate_binary.py -d temp/0907_small -p mv3_s -v

# %%
ot = OpcodeTool()
ot.setup_generator(False, tr.si)
from config import cfg
ot.run(verify = False, out_dir_name = 'golden/mv2', generate_gold_data=True)

# %%
from code_generator.env.sfr import reg
ott = opcode_tools[0] # 1 core system
cs = ott.code_simulator
dp = cs.datapath
csg = cs.control_signal_generator
cg = ott.code_generator
mem = cs.memory
mm = mem.mm # MIDAP Simulator bmem
ms = cs.manager

# %%
np.sum(np.sum(ms.data_info_dict['DWConv1'].data[:,:,:16], axis = 0), axis=0)

# %%
ms.data_info_dict['GlobalPool1'].compare_data

# %%
mem.dram_diff_arr[:80]

# %%
mm.lut

# %%
shape = (4, 112, 64)
diff = mem.diff_arr[3,:np.prod(shape)].reshape(*shape)
np.sum(diff[:1,:1,:16])

# %%
cg.control_op_generator.input_tensor.scale

# %%
# t = cs.memory.diff_arr[2,:32*64*64].reshape(32,64,64)
t = cs.memory.dram_data[0][196608:196608 + 128*128*16].reshape(128,128,16)
t

# %%
np.sum(t[:1,:2,:16])

# %%
d = np.sum(ms.data_info_dict['Conv35'].data ,axis = 0)
d = np.sum(d ,axis = 0)
d

# %%
result = np.right_shift(dp.data_buf.reduction_buf[:1280], 6)

# %%
result = np.where(result > 127, 127, result)
result = np.where(result < -128, -128, result)
result

# %%
mm.fmem[2, :1280].reshape(-1, 64)[:, ::16]

# %%
mem.wmem[-1].reshape(-1,64).shape

# %%
result.reshape(-1, 64)[:,::16]

# %%
dp.input_inst_buf

# %%
csg.input_inst_buf

# %%
csg.wam.offsets

# %%
cs.registers.get_value(reg.wi)

# %%
cs.registers.get_value(reg.wo1)

# %%
cs.registers.get_value(reg.wo2)

# %%
cs.registers.get_value(reg.ro1) # fyo: zunit * s, wyo: 0 / zunit in Arithmetic

# %%
cs.registers.get_value(reg.ro2) # fzo, wzo: (0,  filter size) @ convwrapper,  (system_width, system_width) @ else

# %%
cs.registers.get_value(reg.ro3) # fio, wio: kx offset, (fmap yzplane, wmap yzplane)

# %%
cs.registers.get_value(reg.ro4)# fjo, wjo, fko, wko: ky , kz offset (channel size, channel size, system_width, system_width)

# %%
cs.registers.get_value(reg.rp)

# %%
cs.registers.get_value(reg.ji)

# %%
cs.registers.get_value(reg.bi)

# %%
cs.registers.get_value(reg.ili)

# %%
cs.registers.get_value(reg.oli)

# %%
cs.registers.get_value(reg.cyzi)

# %%
cs.registers.get_value(reg.lps) # cim_type, act_type, bias_type, bias_shift, quant_type, main_shift, act_shift, reduction_type,

# %%
cs.registers.get_value(reg.tvi)

# %%
ms.control_logic.reduction_op.quant_info.__dict__

# %%
cg.initialize()

# %%
cg.control_op_generator.gen_init_code()

# %%
ot.code_generator.config

# %%
from data_structure.attrdict import AttrDict, from_dict_to_attrdict
from_dict_to_attrdict(ot.code_generator.config)

# %%
t = ot.code_generator.config
isinstance(t, dict)

# %%
isinstance(t.DRAM, AttrDict)

# %%
t.SYSTEM

# %%
ot.code_generator.info[0].DRAM.COMM_TYPE

# %%
ot.manager.config.DRAM.COMM_TYPE

# %%
cg.control_op_generator.write_pivot_info

# %%
a = cg.control_op_generator.reduction_output.name
om = cg.control_op_generator.output_mapping[a]

# %%
om

# %%
cg.control_op_generator.write_pivot_info

# %%
cg.control_op_generator.save_write_pivot_info(None, False)
cg.control_op_generator.write_pivot_info

# %%
[(idx, x, x.processing_info.write_logic_type) for idx, x in enumerate(tr.bc.compile_info.layers.values())]

# %%
tr.midap_simulator.memory_controller.memory_manager.dram_dict

# %%
f = tr.midap_simulator.data_info_dict['Conv12'].data

# %%
data = tr.midap_simulator.memory_controller.memory_manager.dram_data[2][458752:458752+8*8*512]

# %%
data = data.reshape(8,8,512)

# %%
f[0,0,:]

# %%
data[0,0,:]

# %%
diff = data-f
diff

# %%
tr.si.processing_order[14].control_info.behavior_info[0].write_info.__dict__

# %%
list(csg.generator)
